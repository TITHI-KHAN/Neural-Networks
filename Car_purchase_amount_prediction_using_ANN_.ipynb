# %% [markdown]
# **Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from warnings import filterwarnings

# %% [markdown]
# **Read data**

# %%
df = pd.read_csv('car_purchasing.csv',encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df.info()
#we can see from the output that there is no null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %% [markdown]
# **Test Train Split**

# %%
X = df.drop(['customer name','customer e-mail','country','car purchase amount','gender'],axis=1)
y = df[['car purchase amount']]

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
X_scaled = MMS.fit_transform(X)
Y_scaled = MMS.fit_transform(y.values.reshape(-1,1))
X_scaled.shape
# Out:
# (500, 4)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,Y_scaled,test_size=0.25,random_state=101)
X_train.shape
# Out:
# (375, 4)

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
model = keras.Sequential([
    layers.Dense(50, activation='relu', input_shape=[4]),
    layers.Dense(25, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(1,activation='linear')
])
model.compile(
    optimizer='adam',
    loss='mean_squared_error',
)

# %%
history = model.fit(X_train, y_train, batch_size=16,validation_split=0.2,epochs=50)
# Out:
# Epoch 1/50
# 19/19 [==============================] - 1s 8ms/step - loss: 0.4136 - val_loss: 0.2167
# Epoch 2/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.1352 - val_loss: 0.0566
# Epoch 3/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0415 - val_loss: 0.0172
# Epoch 4/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0430 - val_loss: 0.0154
# Epoch 5/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0142
# Epoch 6/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0306 - val_loss: 0.0121
# Epoch 7/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0325 - val_loss: 0.0100
# Epoch 8/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0248 - val_loss: 0.0094
# Epoch 9/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0237 - val_loss: 0.0080
# Epoch 10/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0239 - val_loss: 0.0072
# Epoch 11/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0056
# Epoch 12/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0206 - val_loss: 0.0052
# Epoch 13/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0193 - val_loss: 0.0062
# Epoch 14/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0186 - val_loss: 0.0040
# Epoch 15/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0198 - val_loss: 0.0057
# Epoch 16/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0185 - val_loss: 0.0039
# Epoch 17/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0157 - val_loss: 0.0036
# Epoch 18/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0159 - val_loss: 0.0032
# Epoch 19/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0147 - val_loss: 0.0029
# Epoch 20/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0025
# Epoch 21/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0053
# Epoch 22/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0151 - val_loss: 0.0028
# Epoch 23/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0123 - val_loss: 0.0030
# Epoch 24/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0019
# Epoch 25/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0124 - val_loss: 0.0021
# Epoch 26/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0021
# Epoch 27/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0119 - val_loss: 0.0024
# Epoch 28/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0153 - val_loss: 0.0026
# Epoch 29/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.0015
# Epoch 30/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0015
# Epoch 31/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0108 - val_loss: 0.0031
# Epoch 32/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0122 - val_loss: 0.0019
# Epoch 33/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0103 - val_loss: 0.0016
# Epoch 34/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0014
# Epoch 35/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0028
# Epoch 36/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0014
# Epoch 37/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0012
# Epoch 38/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0026
# Epoch 39/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 7.8100e-04
# Epoch 40/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 7.2430e-04
# Epoch 41/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0093 - val_loss: 5.2294e-04
# Epoch 42/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0031
# Epoch 43/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0096 - val_loss: 0.0022
# Epoch 44/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0016
# Epoch 45/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0078 - val_loss: 8.5324e-04
# Epoch 46/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 7.2282e-04
# Epoch 47/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0089 - val_loss: 0.0017
# Epoch 48/50
# 19/19 [==============================] - 0s 3ms/step - loss: 0.0093 - val_loss: 6.2641e-04
# Epoch 49/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0090 - val_loss: 6.6970e-04
# Epoch 50/50
# 19/19 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 5.2076e-04

# %%
plt.figure(figsize=(4,2),dpi=200)
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

plt.title('Model Loss During Training or Validation')
plt.ylabel('Training & Validation Losses')
plt.xlabel('Epoch')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
loss = model.evaluate(X_test, y_test)
print(loss)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 5.2392e-04
# 0.0005239237798377872

# %%
X_random_sample = np.array([[ 55, 65000, 11600, 562341]])
y_predict = model.predict(X_random_sample)
print('Predicted Purchase Amount is =', y_predict[:,0])
# Out:
# 1/1 [==============================] - 0s 62ms/step
# Predicted Purchase Amount is = [222433.98]
